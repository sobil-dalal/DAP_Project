# %% [markdown]
# ## Fetch Distinct Values from MongoDB

# %%
import pandas as pd
from pymongo import MongoClient
import psycopg2
from pandas import DataFrame
import pprint
from sqlalchemy import create_engine

# %%
db_cl = MongoClient('83.212.82.56', 27017)
db = db_cl.DAP_ProjectDB
print("MongoDB connection successfull!")
# Out:
# MongoDB connection successfull!

# %%
collection_hrrp = db.hrrp

# %%
db_list_orig = db['hrrp'].distinct('measure_name')
db_list = [w.replace('-', '_') for w in db_list_orig]

# %% [markdown]
# ### Connect with PostgreSQL and Create a Database named HRRP

# %%
try:
    dbConnection = psycopg2.connect(
    user = "dap",
    password = "dap",
    host = "83.212.82.56",
    port = "5432",
    database = "postgres")
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    dbCursor = dbConnection.cursor()
    dbCursor.execute('CREATE DATABASE hrrp;')
    dbCursor.close()
except (Exception , psycopg2.Error) as dbError :
    print ("Error while connecting to PostgreSQL", dbError)
finally:
    if(dbConnection): dbConnection.close()

# %%
alterString = """
ALTER TABLE weather_new
ALTER COLUMN hospital_name TYPE VARCHAR(100),
ALTER COLUMN provider_id TYPE integer PRIMARY KEY,
ALTER COLUMN state TYPE VARCHAR(2),
ALTER COLUMN measure_name TYPE VARCHAR,
ALTER COLUMN number_of_discharges TYPE integer,
ALTER COLUMN excess_readmission_ratio TYPE float,
ALTER COLUMN predicted_readmission_rate TYPE float,
ALTER COLUMN expected_readmission_rate TYPE float,
ALTER COLUMN number_of_readmissions TYPE integer,
ALTER COLUMN start_date TYPE timestamp,
ALTER COLUMN end_date TYPE timestamp
);
"""

# %%
engine = create_engine('postgresql://dap:dap@83.212.82.56:5432/hrrp', echo=True)

# %% [markdown]
# ### Create and Populate Dynamic Tables in PostgreSQL

# %%
for i in range(len(db_list)):
    cursor = collection_hrrp.find({"measure_name": db_list_orig[i]}, { "_id" : 0 })
    df = pd.DataFrame(list(cursor)) 
    df.to_sql(db_list[i], engine, if_exists = 'append', chunksize = 100)
    with engine.connect() as con:
        con.execute('ALTER TABLE "{}" ADD PRIMARY KEY (provider_id)'.format(db_list[i]))
# Out:
# 2020-04-10 22:23:06,568 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-04-10 22:23:06,569 INFO sqlalchemy.engine.base.Engine {'name': 'READM_30_AMI_HRRP'}
# 2020-04-10 22:23:06,896 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-04-10 22:23:06,907 INFO sqlalchemy.engine.base.Engine INSERT INTO "READM_30_AMI_HRRP" (index, hospital_name, provider_id, state, measure_name, number_of_discharges, excess_readmission_ratio, predicted_readmission_rate, expected_readmission_rate, number_of_readmissions, start_date, end_date, footnote) VALUES (%(index)s, %(hospital_name)s, %(provider_id)s, %(state)s, %(measure_name)s, %(number_of_discharges)s, %(excess_readmission_ratio)s, %(predicted_readmission_rate)s, %(expected_readmission_rate)s, %(number_of_readmissions)s, %(start_date)s, %(end_date)s, %(footnote)s)
# ...
